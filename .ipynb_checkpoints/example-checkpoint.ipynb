# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#     timestamp   latitude   longitude      mag_x     mag_y     mag_z    gyro_x  \
# 0  1545365126    49.3123     128.7256 -0.007500 -0.033736  0.435326 -0.001862
# 1  1545365136    49.1101     129.6300 -0.005916 -0.034064  0.432130 -0.001870
# 2  1545365146    48.9003     130.5266 -0.004318 -0.034326  0.428849 -0.001878
# 3  1545365156    48.6828     131.4152 -0.002707 -0.034521  0.425483 -0.001886
# 4  1545365166    48.4579     132.2957 -0.001088 -0.034650  0.422038 -0.001893
#
#     gyro_y    gyro_z  axis     power  power_norm
# 0 -0.00489 -1.217493     0  4.320224   54.354766
# 1 -0.00489 -1.217493     0  4.358584   54.482985
# 2 -0.00489 -1.217493     0  4.388835   54.584098
# 3 -0.00489 -1.217493     0  4.410955   54.658034
# 4 -0.00489 -1.217493     0  4.424949   54.704809

# %%
X = df.iloc[:,3:8]
Y = df.iloc[:,10]

FEATURES = X.columns 
LABEL = Y.name

scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=FEATURES)
Y = pd.DataFrame(scaler.fit_transform(Y.values.reshape(-1, 1)), columns=[LABEL])

# %%
df['power_exp'] = df['power']/df["power"].max() * 0.5
df.plot(x="timestamp", y=["mag_x", "mag_y", "power_exp"])
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
df.plot(x="timestamp", y=["gyro_x", "gyro_y"])
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
df.plot(x="mag_x", y="mag_y")

# %%
df.plot(x="timestamp", y="power")

# %%
for _alpha in [0.01, 0.05, .1, .2, .3, .4, .5, .6]:
    reg = linear_model.Ridge(alpha=_alpha)
    reg.fit(X,Y)
    print("Alpha: {} | Score: {}".format(_alpha, reg.score(X,Y)))
# Out:
# Alpha: 0.01 | Score: 0.8909504380026699
# Alpha: 0.05 | Score: 0.8909495138289827
# Alpha: 0.1 | Score: 0.8909467756366745
# Alpha: 0.2 | Score: 0.8909367878714962
# Alpha: 0.3 | Score: 0.8909218992663225
# Alpha: 0.4 | Score: 0.890903181153158
# Alpha: 0.5 | Score: 0.8908814672529766
# Alpha: 0.6 | Score: 0.8908574095749235

# %%
from sklearn.kernel_ridge import KernelRidge
best_score = 0
best_alpha = 0
best_gamma = 0
for _alpha in [0.001, 0.005, 0.01, 0.05, .1, .2, .3, .4, .5, .6]:
    for _gamma in range(1,11):
        reg = KernelRidge(kernel="rbf", alpha=_alpha, gamma=_gamma)
        reg.fit(X,Y)
        current_score = reg.score(X,Y)
        print("Alpha: {} | Gamma : {} | Score: {}".format(_alpha, _gamma, current_score))
        if current_score > best_score:
            best_score = current_score
            best_alpha = _alpha
            best_gamma = _gamma
print("Best Score: {} ".format(best_score))
print("Best Alpha: {} ".format(best_alpha))
print("Best Gamma: {} ".format(best_gamma))
# Out:
# Alpha: 0.001 | Gamma : 1 | Score: 0.9756446424782127
# Alpha: 0.001 | Gamma : 2 | Score: 0.9815204589473276
# Alpha: 0.001 | Gamma : 3 | Score: 0.9842523829362229
# Alpha: 0.001 | Gamma : 4 | Score: 0.985761675448374
# Alpha: 0.001 | Gamma : 5 | Score: 0.9869453889813539
# Alpha: 0.001 | Gamma : 6 | Score: 0.9878377501855699
# Alpha: 0.001 | Gamma : 7 | Score: 0.9884962394322664
# Alpha: 0.001 | Gamma : 8 | Score: 0.9890232018624716
# Alpha: 0.001 | Gamma : 9 | Score: 0.9894699659652725
